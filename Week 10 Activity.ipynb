# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the data into python

# %%
data = pd.read_csv('week10.csv')

# %%
data.head()
# Out:
#           ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0   8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 1   9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 2   5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 3  10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 4   8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       18.436525       100.341674   4.628771
# 1       11.558279        31.997993   4.075075
# 2        8.399735        54.917862   2.559708
# 3       13.789695        84.603556   2.672989
# 4       12.363817        62.798309   4.401425

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
# dtypes: float64(9)
# memory usage: 141.5 KB

# %%
data.shape
# Out:
# (2011, 9)

# %% [markdown]
# There are 2011 rows an 9 columns are present in the dataset.

# %% [markdown]
# # 2.Checking for null values

# %%
data.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# No null values in this dataset

# %% [markdown]
# # 3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.

# %%
data.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity'],
#       dtype='object')

# %%
#Retrieving the variables to examine
slice_data=data[['Hardness','Sulfate','Organic_carbon']]
sns.pairplot(slice_data)

# %%
#plotting histogram for 'Hardness'
data.hist(column='Hardness')
# Out:
# array([[<AxesSubplot:title={'center':'Hardness'}>]], dtype=object)

# %%
#Checking outliers in Hardness
plt.boxplot(data['Hardness'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d03a58c280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d03a58c8e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d03a51df70>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d03a58cdc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d03a59a0d0>],
#  'means': []}

# %%
#plotting histogram for 'Sulfate'
data.hist(column='Sulfate')
# Out:
# array([[<AxesSubplot:title={'center':'Sulfate'}>]], dtype=object)

# %%
#Checking outliers in sulfate
plt.boxplot(data['Sulfate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d03a847580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d03a847b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d03a8473d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d03a856130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d03a856400>],
#  'means': []}

# %%
#plotting histogram for 'Organic Carbon'
data.hist(column='Organic_carbon')
# Out:
# array([[<AxesSubplot:title={'center':'Organic_carbon'}>]], dtype=object)

# %%
#Checking outliers in organic carbon
plt.boxplot(data['Organic_carbon'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d03a8b14f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d03a8b1a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d03a8b11f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d03a8be070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d03a8be340>],
#  'means': []}

# %%
#Finding correlation
data1=data[['ph','Chloramines','Conductivity']]
data1.corr()
# Out:
#                     ph  Chloramines  Conductivity
# ph            1.000000    -0.024768      0.014128
# Chloramines  -0.024768     1.000000     -0.028277
# Conductivity  0.014128    -0.028277      1.000000

# %% [markdown]
# ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon' have normal distribution,have outliers and have low correlation

# %% [markdown]
# # 4. Carry out correlation analysis on the dataset and find the correlation factor between
#
# a. ph and Chloramines
#
# b. ph and Conductivity
#
# What do we infer from this correlation value?

# %%
#Finding the correlation values
corrm = data.corr()
corrm
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.108948 -0.087615    -0.024768  0.010524
# Hardness         0.108948  1.000000 -0.053269    -0.022685 -0.108521
# Solids          -0.087615 -0.053269  1.000000    -0.051789 -0.162769
# Chloramines     -0.024768 -0.022685 -0.051789     1.000000  0.006254
# Sulfate          0.010524 -0.108521 -0.162769     0.006254  1.000000
# Conductivity     0.014128  0.011731 -0.005198    -0.028277 -0.016192
# Organic_carbon   0.028375  0.013224 -0.005484    -0.023808  0.026776
# Trihalomethanes  0.018278 -0.015400 -0.015668     0.014990 -0.023347
# Turbidity       -0.035849 -0.034831  0.019409     0.013137 -0.009934
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# ph                   0.014128        0.028375         0.018278  -0.035849
# Hardness             0.011731        0.013224        -0.015400  -0.034831
# ...

# %%
#plotting heatmap
plt.subplots(figsize=(9,7))
sns.heatmap(corrm,vmin=-.2,vmax=0.5,annot=True,linewidth=0.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
data1=data[['ph','Chloramines','Conductivity']]

# %%
corr_new=data1.corr()

# %%
#plotting heatmap for relevent columns
plt.subplots(figsize=(14,8))
sns.heatmap(corr_new,vmin=-.2,vmax=.8,annot=True,linewidth=0.2)
# Out:
# <AxesSubplot:>

# %%
#ph and Chloramines

# %%
data[['ph','Chloramines']].corr()
# Out:
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %% [markdown]
# ph and chloramines have low negative correlation

# %%
#ph and Conductivity

# %%
data[['ph','Conductivity']].corr()
# Out:
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000

# %% [markdown]
# ph and conductivity have low  positive correlation
